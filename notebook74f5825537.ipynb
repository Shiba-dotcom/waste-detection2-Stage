# %% [markdown]
# # 🏆 Hệ thống Nhận diện Rác 2 Giai đoạn (Final Pipeline)
#
# Notebook này thực thi **TOÀN BỘ** quy trình của đồ án từ đầu đến cuối trên Kaggle.
#
# ### 📐 Kiến trúc đã chốt:
# 1. **Stage 1 (Phát hiện vùng rác):** Dùng **YOLOv8s** gốc, đặt `conf=0.15` để quét và lấy bằng được mọi thứ nghi ngờ là rác (Tối đa hóa Recall).
# 2. **Stage 2 (Phân loại & Lọc):** Dùng **EfficientNet-B2** với 6 lớp (Thêm lớp `Background` để lọc các cú lừa từ Stage 1).
#
# ⚠️ **Yêu cầu hệ thống:** GPU (T4 x2 hoặc P100) + Bật Internet.

# %%
# ============================================================
# 1. Tải Mã nguồn & Cài đặt thư viện
# ============================================================
# !git clone https://github.com/Shiba-dotcom/waste-detection2-Stage.git
# !pip install -q ultralytics timm
# Out:
# Cloning into 'waste-detection2-Stage'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 160 (delta 14), reused 23 (delta 7), pack-reused 126 (from 1)
# Receiving objects: 100% (160/160), 101.27 MiB | 42.90 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.3 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 101.8 MB/s eta 0:00:0000:010:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.

# %%
# ============================================================
# 2. Nhập Dữ liệu Ngoại lai (TACO, TrashNet, RealWaste)
# ============================================================
import os, shutil

# !mkdir -p /kaggle/working/waste-detection2-Stage/data/external/TrashNet
# !mkdir -p /kaggle/working/waste-detection2-Stage/data/external/RealWaste
# !mkdir -p /kaggle/working/waste-detection2-Stage/data/raw

datasets_to_copy = [
    {"src": "/kaggle/input/datasets/feyzazkefe/trashnet/dataset-resized",
     "dst": "/kaggle/working/waste-detection2-Stage/data/external/TrashNet"},
    {"src": "/kaggle/input/datasets/sohamchaudhari2004/taco-trash-detection-dataset/data",
     "dst": "/kaggle/working/waste-detection2-Stage/data/raw"},
    {"src": "/kaggle/input/datasets/joebeachcapital/realwaste/realwaste-main/RealWaste",
     "dst": "/kaggle/working/waste-detection2-Stage/data/external/RealWaste"}
]

for task in datasets_to_copy:
    if os.path.exists(task["src"]):
        os.makedirs(task["dst"], exist_ok=True)
        shutil.copytree(task["src"], task["dst"], dirs_exist_ok=True)
        print(f"Đã tải: {os.path.basename(task['src'])}")
    else:
        print(f"Bỏ qua: {task['src']} (Không tìm thấy trên Kaggle Dataset)")
# Out:
# Đã tải: dataset-resized
# Đã tải: data
# Đã tải: RealWaste

# %%
# ============================================================
# 3. Chạy Toàn bộ Tiền xử lý Dữ liệu (Data Pipeline)
# ============================================================
# %cd /kaggle/working/waste-detection2-Stage

print("\n--- 3.1 Dọn dẹp & Tạo nhãn YOLO ---")
# !python src/data_prep/data_cleaning.py
# !python src/Training_dataYolo.py
# !python src/data_prep/split_dataset.py

print("\n--- 3.2 Chuẩn bị dữ liệu cho Stage 2 (Classifier) ---")
# !python src/data_prep/crop_for_classification.py
# !python src/data_prep/merge_external_datasets.py
# !python src/data_prep/generate_background.py

print("\n✅ Hoàn tất chuẩn bị 100% dữ liệu!")
# Out:
# /kaggle/working/waste-detection2-Stage
#
# --- 3.1 Dọn dẹp & Tạo nhãn YOLO ---
# ============================================================
#   DATA CLEANING - TACO Dataset
# ============================================================
#
# [Load] annotations.json ...
#   So anh goc         : 1500
#   So annotations goc : 4784
#   So categories      : 60
#
# ────────────────────────────────────────────────────────────
# [Buoc 1] Kiem tra dong trung lap (Duplicates)
# ────────────────────────────────────────────────────────────
#   Duplicate annotations: 0
#   Duplicate image IDs: 0
#   Duplicate file names: 0
#
# ────────────────────────────────────────────────────────────
# [Buoc 2] Kiem tra gia tri thieu (Missing Values)
# ────────────────────────────────────────────────────────────
#   Images: Tat ca truong bat buoc day du
#   Annotations: Tat ca truong bat buoc day du
#   Anh khong co annotation: 0
#
# ────────────────────────────────────────────────────────────
# [Buoc 3] Kiem tra nhan khong hop le
# ────────────────────────────────────────────────────────────
#   Annotations voi category_id khong hop le: 0
#   Categories khong co trong mapping.csv: 1
#     - 'Rope & strings' -> se mac dinh vao 'Other'
#
# ────────────────────────────────────────────────────────────
# [Buoc 4] Kiem tra & loai bo BBox bat thuong
# ────────────────────────────────────────────────────────────
#   Tong BBox bat thuong: 8
#     - negative_position: 7
#     - too_small: 1
#     -> Da loai bo 8 annotations bat thuong
#
# ────────────────────────────────────────────────────────────
# [Buoc 5] Kiem tra anh loi, truncated, grayscale, kich thuoc
# ────────────────────────────────────────────────────────────
#   Anh hop le          : 1500
#   Anh loi (header)     : 0
#   Anh truncated (body) : 0
#   Anh grayscale        : 0
#   Anh qua nho (<32px) : 0
#
# ────────────────────────────────────────────────────────────
# [Buoc 6] Thong ke sau khi cleaning
# ────────────────────────────────────────────────────────────
#   So anh sau cleaning       : 1500
#   So annotations sau cleaning: 4776
#
# Tong so da loai bo/sua:
#     - bbox_anomaly: 8
#     TONG: 8
#
# ────────────────────────────────────────────────────────────
# [Buoc 7] Preview kiem tra YOLO label validity
# ────────────────────────────────────────────────────────────
#   YOLO labels se co gia tri ngoai [0,1]: 0
#   -> Tat ca labels se hop le khi convert sang YOLO format!
#
# ────────────────────────────────────────────────────────────
# [Buoc 8] Luu annotations_cleaned.json
# ────────────────────────────────────────────────────────────
#   Da luu: /kaggle/working/waste-detection2-Stage/data/raw/annotations_cleaned.json
#     Images     : 1500
#     Annotations: 4776
#   Da luu bao cao: /kaggle/working/waste-detection2-Stage/results/bao_cao_cleaning.csv
#
# ============================================================
#   [HOAN TAT] Data Cleaning xong!
#   Su dung 'annotations_cleaned.json' cho cac buoc tiep theo
# ============================================================
# [INFO] Su dung annotations_cleaned.json (da lam sach)
#
# [INFO] Đang xử lý chế độ: MULTI-CLASS (5 classes)...
#        Đang copy hình ảnh...
#        Đang tạo file nhãn YOLO...
#        => Đã xử lý xong (MULTI-CLASS (5 classes)).
#
# [INFO] Đang xử lý chế độ: BINARY (1 class: Waste)...
#        Đang copy hình ảnh...
#        Đang tạo file nhãn YOLO...
#        => Đã xử lý xong (BINARY (1 class: Waste)).
#
# [HOÀN TẤT] Cả 2 bộ dữ liệu đã được tạo thành công!
# \n========== Splitting processed ==========
# Found 1500 images
# num_classes = 5
#
# Split result
# Train: 1045
# Val  : 225
# Test : 230
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/images/batch_9
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/images/batch_8
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/images/batch_7
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/images/batch_6
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/images/batch_5
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/images/batch_4
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/images/batch_3
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/images/batch_2
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/images/batch_15
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/images/batch_14
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/images/batch_13
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/images/batch_12
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/images/batch_11
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/images/batch_10
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/images/batch_1
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/labels/batch_9
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/labels/batch_8
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/labels/batch_7
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/labels/batch_6
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/labels/batch_5
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/labels/batch_4
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/labels/batch_3
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/labels/batch_2
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/labels/batch_15
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/labels/batch_14
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/labels/batch_13
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/labels/batch_12
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/labels/batch_11
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/labels/batch_10
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed/labels/batch_1
#
# Done.
#
# Verification
# train: images=1045, labels=1045
# val  : images=225, labels=225
# test : images=230, labels=230
# \n========== Splitting processed_binary ==========
# Found 1500 images
# num_classes = 1
#
# Split result
# Train: 1050
# Val  : 225
# Test : 225
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/images/batch_9
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/images/batch_8
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/images/batch_7
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/images/batch_6
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/images/batch_5
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/images/batch_4
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/images/batch_3
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/images/batch_2
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/images/batch_15
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/images/batch_14
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/images/batch_13
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/images/batch_12
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/images/batch_11
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/images/batch_10
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/images/batch_1
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/batch_9
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/batch_8
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/batch_7
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/batch_6
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/batch_5
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/batch_4
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/batch_3
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/batch_2
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/batch_15
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/batch_14
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/batch_13
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/batch_12
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/batch_11
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/batch_10
# Removed empty dir: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/batch_1
#
# Done.
#
# Verification
# train: images=1050, labels=1050
# val  : images=225, labels=225
# test : images=225, labels=225
#
# --- 3.2 Chuẩn bị dữ liệu cho Stage 2 (Classifier) ---
# ============================================================
#   CROP FOR CLASSIFICATION - Stage 2 Dataset
# ============================================================
#   Input  : /kaggle/working/waste-detection2-Stage/data/processed
#   Output : /kaggle/working/waste-detection2-Stage/data/classification
#   Crop size : 224x224
#   Padding   : 10%
#   Oversample (train only): {'Glass': 2, 'Metal': 1, 'Other': 0, 'Paper': 1, 'Plastic': 0}
# ============================================================
#
# [TRAIN] Tim thay 1045 anh
#
#   [TRAIN] Tong: 4444 crops
#     Glass     :   585  █████████████████████████████
#     Metal     :   696  ██████████████████████████████████
#     Other     :   954  ███████████████████████████████████████████████
#     Paper     :   692  ██████████████████████████████████
#     Plastic   :  1517  ███████████████████████████████████████████████████████████████████████████
#
# [VAL] Tim thay 225 anh
#
#   [VAL] Tong: 744 crops
#     Glass     :    27  █
#     Metal     :    99  ████
#     Other     :   269  █████████████
#     Paper     :    70  ███
#     Plastic   :   279  █████████████
#
# [TEST] Tim thay 230 anh
#
#   [TEST] Tong: 672 crops
#     Glass     :    32  █
#     Metal     :   103  █████
#     Other     :   188  █████████
#     Paper     :    74  ███
#     Plastic   :   275  █████████████
#
# ============================================================
#   TONG CONG: 5860 crops
#   Luu tai: /kaggle/working/waste-detection2-Stage/data/classification
# ============================================================
#
#   [INFO] Ty le max/min trong tap train: 2.6:1
#   [OK] Muc can bang chap nhan duoc.
#
# [HOAN TAT] Crop xong! Dataset san sang cho Stage 2.
# =================================================================
#   MERGE EXTERNAL DATASETS - Classification Stage 2
# =================================================================
#   Moi truong  : Kaggle
#   TACO crops  : /kaggle/working/waste-detection2-Stage/data/classification
#   TrashNet    : /kaggle/working/waste-detection2-Stage/data/external/TrashNet
#   RealWaste   : /kaggle/working/waste-detection2-Stage/data/external/RealWaste
#   Output      : /kaggle/working/waste-detection2-Stage/data/classification_merged
#   Max/class   : 2500
# =================================================================
#
# [Buoc 1] Thu thap TACO crops...
#   [train] 3199 anh
#   [val] 656 anh
#   [test] 588 anh
#
# [Buoc 2] Thu thap TrashNet...
#   Glass     :   501
#   Metal     :   410
#   Other     :   137
#   Paper     :   997
#   Plastic   :   482
#
# [Buoc 3] Thu thap RealWaste...
#   Glass     :   420
#   Metal     :   790
#   Other     :  1660
#   Paper     :   961
#   Plastic   :   921
#
# [Buoc 4] Chia dataset ngoai thanh train/val/test...
#   Glass     : train= 645 val= 138 test= 138
#   Metal     : train= 840 val= 180 test= 180
#   Other     : train=1259 val= 269 test= 269
#   Paper     : train=1372 val= 293 test= 293
#   Plastic   : train= 983 val= 210 test= 210
#
# [Buoc 5] Gop va copy anh...
#
#   --- TRAIN ---
#     Glass     : 567 (TACO) + 645 (ext) = 1212
#     Metal     : 568 (TACO) + 840 (ext) = 1408
#     Other     : 746 (TACO) + 1259 (ext) = 2005
#     Paper     : 526 (TACO) + 1372 (ext) = 1898
#     Plastic   : 792 (TACO) + 983 (ext) = 1775
#
#   --- VAL ---
#     Glass     : 26 (TACO) + 138 (ext) = 164
#     Metal     : 92 (TACO) + 180 (ext) = 272
#     Other     : 254 (TACO) + 269 (ext) = 523
#     Paper     : 66 (TACO) + 293 (ext) = 359
#     Plastic   : 218 (TACO) + 210 (ext) = 428
#
#   --- TEST ---
#     Glass     : 31 (TACO) + 138 (ext) = 169
#     Metal     : 96 (TACO) + 180 (ext) = 276
#     Other     : 174 (TACO) + 269 (ext) = 443
#     Paper     : 72 (TACO) + 293 (ext) = 365
#     Plastic   : 215 (TACO) + 210 (ext) = 425
#
# =================================================================
#   THONG KE CUOI CUNG
# =================================================================
#
#   [TRAIN] Tong: 8298
#     Glass     :  1212  ████████████████████████████████████████
#     Metal     :  1408  ██████████████████████████████████████████████
#     Other     :  2005  ██████████████████████████████████████████████████████████████████
#     Paper     :  1898  ███████████████████████████████████████████████████████████████
#     Plastic   :  1775  ███████████████████████████████████████████████████████████
#
#   [VAL] Tong: 1746
#     Glass     :   164  █████
#     Metal     :   272  █████████
#     Other     :   523  █████████████████
#     Paper     :   359  ███████████
#     Plastic   :   428  ██████████████
#
#   [TEST] Tong: 1678
#     Glass     :   169  █████
#     Metal     :   276  █████████
#     Other     :   443  ██████████████
#     Paper     :   365  ████████████
#     Plastic   :   425  ██████████████
#
#   Ty le max/min (train): 1.7:1
#   [OK] Can bang tot!
#
#   Dataset merged luu tai: /kaggle/working/waste-detection2-Stage/data/classification_merged
# =================================================================
# [HOAN TAT] Merge xong!
# =================================================================
#   GENERATE BACKGROUND CLASS - Stage 2
# =================================================================
#   Source (Binary) : /kaggle/working/waste-detection2-Stage/data/processed_binary
#   Output (Merged) : /kaggle/working/waste-detection2-Stage/data/classification_merged
# =================================================================
#
# [XỬ LÝ] Split: TRAIN
# Generating train: 100%|█████████████████████████████████████████| 2500/2500 [03:12<00:00, 12.99it/s]
#   -> Đã tạo 2500/2500 ảnh Background cho train.
#
# [XỬ LÝ] Split: VAL
# Generating val: 100%|█████████████████████████████████████████████| 400/400 [00:28<00:00, 13.82it/s]
#   -> Đã tạo 400/400 ảnh Background cho val.
#
# [XỬ LÝ] Split: TEST
# Generating test: 100%|████████████████████████████████████████████| 400/400 [00:27<00:00, 14.78it/s]
#   -> Đã tạo 400/400 ảnh Background cho test.
#
# =================================================================
#   [HOÀN TẤT] Sinh dữ liệu Background thành công!
#   Hãy cập nhật train_stage2_classifier.py đổi NUM_CLASSES = 6
#   Và CLASS_NAMES = ['Background', 'Glass', 'Metal', 'Other', 'Paper', 'Plastic']
# =================================================================
#
# ✅ Hoàn tất chuẩn bị 100% dữ liệu!

# %%
# ============================================================
# 4. Huấn luyện Stage 1 (YOLOv8s - Binary Detector)
# BỎ QUA CELL NÀY NẾU BẠN ĐÃ CÓ FILE stage1_best.pt
# ============================================================
from ultralytics import YOLO
import time
from pathlib import Path

DATASET_YAML = "/kaggle/working/waste-detection2-Stage/data/processed_binary/dataset.yaml"
OUTPUT_DIR   = "/kaggle/working/waste-detection2-Stage/results/yolo8s_runs"

# Kiểm tra xem đã có model train sẵn chưa để bỏ qua
if not Path("stage1_best.pt").exists():
    print("🚀 Bắt đầu train Stage 1 (YOLOv8s)")
    model_s = YOLO("yolov8s.pt")
    t0 = time.time()
    model_s.train(
        data=DATASET_YAML, imgsz=640, epochs=100, batch=16, patience=20,
        optimizer="auto", lr0=0.01, cos_lr=True, augment=True, workers=4,
        project=OUTPUT_DIR, name="stage1", exist_ok=True, save=True, save_period=-1,
    )
    print(f"\n✅ Train Stage 1 hoàn tất sau {(time.time()-t0)/60:.1f} phút")
    
    # Copy model tốt nhất ra thư mục gốc để dễ dùng
    # !cp results/yolo8s_runs/stage1/weights/best.pt stage1_best.pt
else:
    print("⏭️ Đã tìm thấy 'stage1_best.pt', bỏ qua bước huấn luyện Stage 1.")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 🚀 Bắt đầu train Stage 1 (YOLOv8s)
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 151.6MB/s 0.1s0.1s<0.1s
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=True, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/waste-detection2-Stage/data/processed_binary/dataset.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=stage1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/waste-detection2-Stage/results/yolo8s_runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/waste-detection2-Stage/results/yolo8s_runs/stage1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 17.2MB/s 0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, 16, None, [128, 256, 512]]
# Model summary: 130 layers, 11,135,987 parameters, 11,135,971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 69.6MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3276.6±2350.2 MB/s, size: 1446.0 KB)
# train: Scanning /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/train/batch_1... 1050 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1050/1050 1.2Kit/s 0.9s1ss
# train: New cache created: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/train/batch_1.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1834.7±1763.9 MB/s, size: 1891.3 KB)
# val: Scanning /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/val/batch_1... 225 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 225/225 1.1Kit/s 0.2s<0.4s
# val: New cache created: /kaggle/working/waste-detection2-Stage/data/processed_binary/labels/val/batch_1.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /kaggle/working/waste-detection2-Stage/results/yolo8s_runs/stage1/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/waste-detection2-Stage/results/yolo8s_runs/stage1
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      3.75G      1.204      2.076      1.163         10        640: 100% ━━━━━━━━━━━━ 66/66 1.6it/s 40.6s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.8it/s 4.3s0.4ss
#                    all        225        842      0.537      0.279      0.306      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      4.89G      1.452      1.656      1.266         10        640: 100% ━━━━━━━━━━━━ 66/66 1.9it/s 35.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.373      0.265      0.229      0.145
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      4.89G      1.515      1.757      1.332         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.221      0.194      0.111     0.0602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      4.89G      1.556      1.771       1.35         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 39.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.6it/s 2.2s0.3s
#                    all        225        842      0.427      0.284      0.247      0.146
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      4.89G      1.492      1.695      1.318         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.6it/s 2.2s0.3s
#                    all        225        842      0.436      0.251       0.24      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      4.89G      1.483      1.645      1.313         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.6it/s 2.2s0.3s
#                    all        225        842      0.347      0.254      0.201      0.121
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      4.89G      1.439      1.595      1.273         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.6it/s 2.2s0.3s
#                    all        225        842      0.425      0.316      0.277      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      4.89G      1.411      1.554      1.258         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.1it/s 2.0s0.3s
#                    all        225        842      0.477       0.26      0.276      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      4.89G      1.394      1.509      1.259         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.1it/s 1.9s0.3s
#                    all        225        842      0.476      0.262       0.27      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      4.89G      1.393      1.544      1.256         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.6it/s 2.2s0.3s
#                    all        225        842      0.465      0.282      0.277       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.89G      1.343       1.47      1.227         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.0it/s 2.0s0.3s
#                    all        225        842      0.489      0.336      0.312      0.202
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      4.89G      1.328      1.465      1.225         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.476       0.31      0.311      0.197
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      4.89G      1.346      1.466      1.228         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.1it/s 1.9s0.3s
#                    all        225        842      0.464      0.327       0.32       0.21
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      4.89G      1.323      1.407      1.212         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.5it/s 2.3s0.3s
#                    all        225        842      0.502        0.3        0.3      0.198
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.89G      1.308      1.439      1.204         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.0it/s 2.0s0.3s
#                    all        225        842      0.456      0.356      0.347      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      4.89G      1.282      1.388      1.179         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.2it/s 1.9s0.3s
#                    all        225        842      0.503      0.325      0.331      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      4.89G      1.215      1.319      1.166         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.2it/s 1.9s0.3s
#                    all        225        842      0.473      0.301      0.296      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      4.89G      1.255      1.363      1.181         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.0it/s 2.0s0.3s
#                    all        225        842      0.525      0.348      0.346      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      4.89G       1.25      1.344      1.165         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 37.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.7it/s 2.2s0.3s
#                    all        225        842      0.552      0.348      0.365      0.238
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      4.89G      1.227       1.33      1.166         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.0it/s 2.0s0.3s
#                    all        225        842      0.544      0.335      0.345      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      4.89G      1.215      1.315      1.148         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.509      0.357      0.364       0.24
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      4.89G       1.22      1.291       1.16         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.1s0.3s
#                    all        225        842      0.545       0.34      0.368      0.247
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      4.89G      1.215      1.251      1.153         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 39.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.565      0.376      0.389      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      4.89G      1.192      1.233      1.136         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.512      0.392      0.377      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      4.89G       1.19      1.234       1.15         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.1it/s 1.9s0.3s
#                    all        225        842      0.572      0.334      0.361      0.238
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      4.89G      1.174      1.225      1.144         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.7it/s 2.2s0.3s
#                    all        225        842      0.586      0.349      0.381      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      4.89G       1.16      1.177      1.119         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.1s0.3s
#                    all        225        842      0.499      0.374       0.37      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      4.89G      1.155      1.193      1.127         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.6it/s 2.2s0.3s
#                    all        225        842       0.56      0.336      0.367      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      4.89G      1.153      1.219      1.123         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.0s0.3s
#                    all        225        842      0.605      0.342       0.37      0.253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      4.89G      1.146      1.177      1.107         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.2it/s 1.9s0.3s
#                    all        225        842      0.646      0.322      0.377      0.253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      4.89G      1.127      1.158      1.092         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.538      0.375      0.389      0.261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      4.89G      1.124      1.135      1.102         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.0it/s 2.0s0.3s
#                    all        225        842      0.584      0.353      0.393      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      4.89G      1.099      1.125      1.085         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 37.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.1s0.3s
#                    all        225        842      0.573      0.367      0.397      0.265
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      4.89G      1.078      1.073      1.082         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.0it/s 2.0s0.3s
#                    all        225        842      0.482      0.382      0.368      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      4.89G      1.109      1.116      1.102         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.617      0.354      0.401      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      4.89G      1.072      1.098      1.089         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 37.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.4it/s 2.4s0.3s
#                    all        225        842      0.571      0.361      0.375       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      4.89G      1.097      1.084      1.086         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.1s0.3s
#                    all        225        842      0.635      0.339      0.386      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      4.89G      1.065      1.068      1.079         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.7it/s 2.2s0.3s
#                    all        225        842      0.535      0.406      0.408      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      4.89G      1.051      1.049      1.073         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 39.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.7it/s 2.1s0.3s
#                    all        225        842      0.586      0.374      0.406      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      4.89G      1.059      1.056      1.067         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.1s0.3s
#                    all        225        842      0.573      0.379      0.398       0.27
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      4.89G      1.042      1.038      1.068         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.0it/s 2.0s0.3s
#                    all        225        842      0.574      0.378      0.401      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      4.89G       1.06      1.036      1.076         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.7it/s 2.2s0.3s
#                    all        225        842      0.578      0.398      0.409      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      4.89G      1.039      1.022      1.059         10        640: 100% ━━━━━━━━━━━━ 66/66 1.9it/s 35.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842        0.6      0.387      0.416      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      4.89G      1.038     0.9962      1.066         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.1it/s 2.0s0.3s
#                    all        225        842      0.632      0.384      0.413      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      4.89G       1.01     0.9807      1.049         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.7it/s 2.1s0.3s
#                    all        225        842       0.59      0.378      0.394      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      4.89G     0.9954      0.971      1.052         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 37.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.6it/s 2.2s0.3s
#                    all        225        842      0.639      0.363      0.422      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      4.89G      1.009      0.965      1.041         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.509      0.417      0.408      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      4.89G      1.011      0.965      1.046         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 37.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.6it/s 2.2s0.3s
#                    all        225        842      0.593      0.365      0.406       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      4.89G      1.008     0.9295      1.039         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842       0.54      0.405      0.408      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      4.89G     0.9824     0.9201      1.033         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 39.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.0it/s 2.0s0.3s
#                    all        225        842      0.577      0.394      0.421      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      4.89G     0.9858     0.9192      1.029         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 35.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.1s0.3s
#                    all        225        842      0.529      0.401      0.409      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      4.89G     0.9635     0.9026      1.023         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.609      0.376      0.407      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      4.89G      0.946     0.8855      1.023         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.604      0.403      0.436      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      4.89G      0.963     0.8792       1.02         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.7s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.1s0.3s
#                    all        225        842      0.579      0.388      0.418      0.286
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      4.89G     0.9306     0.8592      1.012         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 39.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.2it/s 1.9s0.3s
#                    all        225        842      0.651      0.361      0.418       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      4.89G     0.9583     0.8883       1.03         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 37.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.0s0.3s
#                    all        225        842      0.585      0.413      0.425      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      4.89G     0.9278     0.8441      1.006         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.6it/s 2.2s0.3s
#                    all        225        842       0.58      0.428      0.445      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      4.89G     0.9392     0.8412      1.019         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.3s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.7it/s 2.2s0.3s
#                    all        225        842      0.652      0.412       0.45      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      4.89G     0.8927      0.809     0.9953         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.3s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.6it/s 2.2s0.3s
#                    all        225        842      0.651      0.382       0.44      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      4.89G     0.9125      0.817      1.014         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.2s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.1it/s 2.0s0.3s
#                    all        225        842      0.561      0.428       0.42      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      4.89G     0.9003     0.8128      1.001         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.616      0.419      0.445      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      4.89G     0.8916     0.7852     0.9946         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.6it/s 2.2s0.3s
#                    all        225        842      0.625      0.407      0.433      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      4.89G     0.8881     0.7727     0.9861         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.0it/s 2.0s0.3s
#                    all        225        842      0.569      0.411      0.424      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      4.89G     0.8962     0.7783     0.9921         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.7it/s 2.2s0.3s
#                    all        225        842      0.631       0.41      0.448      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      4.89G     0.8635     0.7602     0.9839         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.0it/s 2.0s0.3s
#                    all        225        842      0.605        0.4       0.43      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      4.89G     0.8827      0.778     0.9815         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 37.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.0it/s 2.0s0.3s
#                    all        225        842      0.571       0.42      0.432      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      4.89G     0.8611     0.7484     0.9821         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.564      0.428      0.439      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      4.89G     0.8697     0.7281     0.9656         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.6it/s 2.2s0.3s
#                    all        225        842      0.558      0.436      0.438      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      4.89G     0.8595     0.7271     0.9759         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.1s0.3s
#                    all        225        842      0.559      0.418      0.421      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      4.89G     0.8604     0.7199     0.9744         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.3it/s 1.9s0.3s
#                    all        225        842      0.644      0.411      0.438      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      4.89G     0.8635     0.7164     0.9731         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.608      0.429      0.446      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      4.89G     0.8362     0.7118     0.9819         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.619      0.407      0.435      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      4.89G     0.8367      0.698     0.9735         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.7s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.2it/s 1.9s0.3s
#                    all        225        842      0.599      0.433      0.439      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      4.89G     0.8279     0.6805     0.9563         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.1it/s 1.9s0.3s
#                    all        225        842       0.58      0.432       0.44      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      4.89G     0.8359     0.7024     0.9725         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 37.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.571      0.426      0.439      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      4.89G     0.8413     0.6893     0.9736         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.3s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.1it/s 2.0s0.3s
#                    all        225        842      0.604      0.421      0.444      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      4.89G     0.8325     0.6715     0.9618         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.654      0.414      0.446      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      4.89G       0.82     0.6665     0.9656         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.0s0.3s
#                    all        225        842      0.614      0.435      0.447      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      4.89G      0.827      0.667     0.9536         10        640: 100% ━━━━━━━━━━━━ 66/66 1.9it/s 35.7s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.5it/s 2.3s0.3s
#                    all        225        842      0.619      0.425      0.446      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      4.89G     0.8135     0.6537     0.9597         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.3s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.7it/s 2.2s0.3s
#                    all        225        842      0.618      0.422      0.442      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      4.89G     0.7761     0.6406     0.9514         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.1s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.1it/s 1.9s0.3s
#                    all        225        842      0.622       0.42      0.449      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      4.89G      0.802     0.6467     0.9554         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.1s0.3s
#                    all        225        842      0.617      0.429      0.445      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      4.89G     0.8061     0.6479     0.9509         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.4it/s 2.4s0.4s
#                    all        225        842      0.627      0.428      0.454      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      4.89G     0.7852     0.6321     0.9481         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.688      0.405      0.456      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      4.89G     0.8036     0.6414      0.957         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842       0.63      0.414      0.449      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      4.89G     0.7826     0.6397      0.943         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.571      0.442       0.45      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      4.89G     0.7611     0.6158     0.9366         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.632      0.418      0.453      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      4.89G     0.7684     0.6009     0.9522         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.6it/s 2.2s0.3s
#                    all        225        842      0.585      0.444      0.455      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      4.89G      0.769     0.6136     0.9429         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 38.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.578      0.445      0.455       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      4.89G     0.7693     0.6149     0.9474         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.6it/s 2.2s0.3s
#                    all        225        842      0.616      0.419      0.451      0.316
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      4.89G     0.7163     0.6012     0.8964         10        640: 100% ━━━━━━━━━━━━ 66/66 1.6it/s 40.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.0s0.3s
#                    all        225        842      0.631      0.401      0.437      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      4.89G      0.716     0.5719     0.9013         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.1s0.3s
#                    all        225        842      0.594      0.425      0.439      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      4.89G      0.705     0.5753     0.8966         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.6s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.1s0.3s
#                    all        225        842        0.6      0.425      0.443      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      4.89G     0.7051     0.5575     0.8954         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 35.7s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.8it/s 2.1s0.3s
#                    all        225        842      0.586      0.428      0.441      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      4.89G     0.7077     0.5551     0.9022         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.6s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.1s0.3s
#                    all        225        842      0.613      0.424      0.444      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      4.89G     0.6975     0.5343     0.8861         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 37.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.2it/s 1.9s0.3s
#                    all        225        842      0.609      0.417      0.444      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      4.89G     0.6951     0.5349     0.8934         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.3it/s 1.8s0.3s
#                    all        225        842      0.647      0.404      0.443      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      4.89G     0.6942     0.5428     0.8944         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 35.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 4.3it/s 1.9s0.3s
#                    all        225        842      0.624      0.406      0.443       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      4.89G      0.701      0.543     0.8833         10        640: 100% ━━━━━━━━━━━━ 66/66 1.8it/s 36.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.9it/s 2.1s0.3s
#                    all        225        842      0.602      0.421      0.444       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      4.89G     0.6861     0.5352     0.8897         10        640: 100% ━━━━━━━━━━━━ 66/66 1.7it/s 37.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.7it/s 2.2s0.3s
#                    all        225        842      0.615      0.419      0.445       0.31
#
# 100 epochs completed in 1.124 hours.
# Optimizer stripped from /kaggle/working/waste-detection2-Stage/results/yolo8s_runs/stage1/weights/last.pt, 22.5MB
# Optimizer stripped from /kaggle/working/waste-detection2-Stage/results/yolo8s_runs/stage1/weights/best.pt, 22.5MB
#
# Validating /kaggle/working/waste-detection2-Stage/results/yolo8s_runs/stage1/weights/best.pt...
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.1it/s 7.2s0.8ss
#                    all        225        842      0.617      0.426      0.456      0.325
# Speed: 0.2ms preprocess, 19.7ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /kaggle/working/waste-detection2-Stage/results/yolo8s_runs/stage1
#
# ✅ Train Stage 1 hoàn tất sau 68.0 phút

# %%
# ============================================================
# 5. Huấn luyện Stage 2 (EfficientNet-B2 - 6 Lớp Classifier)
# ============================================================
# Train với các cơ chế: Freeze/Unfreeze, Dropout 0.4, RandAugment, Class Weights

# !python src/train_stage2_classifier.py
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [INFO] PyTorch : 2.10.0+cu128
# [INFO] timm    : 1.0.26
# [INFO] CUDA    : True
# [INFO] GPU     : Tesla T4
# [INFO] Device: cuda
# [INFO] Data  : /kaggle/working/waste-detection2-Stage/data/classification_merged
# [INFO] Augmentation đã được tăng cường:
#   + RandAugment(num_ops=2, magnitude=9)
#   + RandomVerticalFlip(p=0.2)
#   + RandomErasing(p=0.3)
#   + ColorJitter mạnh hơn (brightness/contrast 0.4)
#   + RandomRotation(30°)
# ============================================================
#   LOADING DATASET
# ============================================================
#   Lớp phát hiện : ['Background', 'Glass', 'Metal', 'Other', 'Paper', 'Plastic']  (6 lớp)
#   [OK]   val: lớp khớp với train
#   [OK]   test: lớp khớp với train
#
#   [1/3] Cap Plastic ≤ 2500 mẫu
#   Phân bố TRƯỚC khi cap:
#     Background: 2,500
#          Glass: 1,212
#          Metal: 1,408
#          Other: 2,005
#          Paper: 1,898
#        Plastic: 1,775
#
#   Phân bố SAU khi cap:
#     Background: 2,500
#          Glass: 1,212
#          Metal: 1,408
#          Other: 2,005
#          Paper: 1,898
#        Plastic: 1,775
#
#   [2/3] Tạo WeightedRandomSampler
#   Số mẫu mỗi epoch: 10,798
#
#   [3/3] Tính class weights cho CrossEntropyLoss
#     Background: weight = 0.7199  (n=2,500)
#          Glass: weight = 1.4849  (n=1,212)
#          Metal: weight = 1.2782  (n=1,408)
#          Other: weight = 0.8976  (n=2,005)
#          Paper: weight = 0.9482  (n=1,898)
#        Plastic: weight = 1.0139  (n=1,775)
#
#   Train batches/epoch : 337
#   Val   batches       : 68
#   Test  batches       : 65
# model.safetensors: 100%|███████████████████| 36.8M/36.8M [00:00<00:00, 57.2MB/s]
# [INFO] EfficientNet-B2 (Phase 1 – Frozen backbone)
#   Tổng params      :    7,709,448
#   Trainable params :        8,454  (chỉ classifier head)
#   Frozen params    :    7,700,994  (backbone)
#   Classifier head  : Dropout(0.4) → Linear(1408 → 6)
# [INFO] Loss      : CrossEntropyLoss (weighted, label_smoothing=0.1)
# [INFO] Optimizer : AdamW Phase1 (lr=5e-04, wd=0.0003)
# [INFO] Scheduler : CosineAnnealingLR (T_max Phase1=10)
# [INFO] AMP       : Enabled
#
# ======================================================================
#   BẮT ĐẦU HUẤN LUYỆN 2 GIAI ĐOẠN
#   Phase 1: epoch  1 → 10 (backbone FROZEN,   lr=5e-04)
#   Phase 2: epoch 11 → 60  (backbone UNFROZEN, lr=5e-05)
# ======================================================================
#
# Epoch   1/60  🧊 P1  lr=5.00e-04
# --------------------------------------------------
#   Train: loss=1.4070  acc=0.5057
#   Val  : loss=1.3176  acc=0.5713  (gap=-0.0655)
#   Time : 67.8s
#   ★ New best! Val Acc = 0.5713
#
# Epoch   2/60  🧊 P1  lr=4.88e-04
# --------------------------------------------------
#   Train: loss=1.2301  acc=0.6013
#   Val  : loss=1.2593  acc=0.5932  (gap=+0.0081)
#   Time : 59.4s
#   ★ New best! Val Acc = 0.5932
#
# Epoch   3/60  🧊 P1  lr=4.52e-04
# --------------------------------------------------
#   Train: loss=1.1923  acc=0.6210
#   Val  : loss=1.2470  acc=0.5932  (gap=+0.0278)
#   Time : 59.2s
#
# Epoch   4/60  🧊 P1  lr=3.97e-04
# --------------------------------------------------
#   Train: loss=1.1838  acc=0.6263
#   Val  : loss=1.2196  acc=0.6258  (gap=+0.0005)
#   Time : 58.8s
#   ★ New best! Val Acc = 0.6258
#
# Epoch   5/60  🧊 P1  lr=3.27e-04
# --------------------------------------------------
#   Train: loss=1.1718  acc=0.6351
#   Val  : loss=1.2062  acc=0.6258  (gap=+0.0093)
#   Time : 58.5s
#
# Epoch   6/60  🧊 P1  lr=2.50e-04
# --------------------------------------------------
#   Train: loss=1.1661  acc=0.6373
#   Val  : loss=1.1966  acc=0.6319  (gap=+0.0055)
#   Time : 59.3s
#   ★ New best! Val Acc = 0.6319
#
# Epoch   7/60  🧊 P1  lr=1.73e-04
# --------------------------------------------------
#   Train: loss=1.1439  acc=0.6474
#   Val  : loss=1.2143  acc=0.6212  (gap=+0.0263)
#   Time : 59.0s
#   ⏳ Early stop counter: 1/12
#
# Epoch   8/60  🧊 P1  lr=1.03e-04
# --------------------------------------------------
#   Train: loss=1.1750  acc=0.6320
#   Val  : loss=1.1913  acc=0.6347  (gap=-0.0026)
#   Time : 59.7s
#   ★ New best! Val Acc = 0.6347
#
# Epoch   9/60  🧊 P1  lr=4.77e-05
# --------------------------------------------------
#   Train: loss=1.1683  acc=0.6365
#   Val  : loss=1.1888  acc=0.6365  (gap=-0.0000)
#   Time : 59.8s
#   ★ New best! Val Acc = 0.6365
#
# Epoch  10/60  🧊 P1  lr=1.22e-05
# --------------------------------------------------
#   Train: loss=1.1454  acc=0.6524
#   Val  : loss=1.1872  acc=0.6328  (gap=+0.0196)
#   Time : 59.0s
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🔓 PHASE 2: Unfreeze toàn bộ backbone – Fine-tune với lr=5e-05
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Trainable params: 7,709,448
#
# Epoch  11/60  🔥 P2  lr=5.00e-05
# --------------------------------------------------
#   Train: loss=1.0599  acc=0.6924
#   Val  : loss=1.0237  acc=0.7209  (gap=-0.0285)
#   Time : 72.0s
#   ★ New best! Val Acc = 0.7209
#
# Epoch  12/60  🔥 P2  lr=5.00e-05
# --------------------------------------------------
#   Train: loss=0.9011  acc=0.7700
#   Val  : loss=0.9179  acc=0.7912  (gap=-0.0212)
#   Time : 64.7s
#   ★ New best! Val Acc = 0.7912
#
# Epoch  13/60  🔥 P2  lr=4.98e-05
# --------------------------------------------------
#   Train: loss=0.8277  acc=0.8119
#   Val  : loss=0.8775  acc=0.8085  (gap=+0.0034)
#   Time : 64.6s
#   ★ New best! Val Acc = 0.8085
#
# Epoch  14/60  🔥 P2  lr=4.96e-05
# --------------------------------------------------
#   Train: loss=0.7757  acc=0.8385
#   Val  : loss=0.8508  acc=0.8206  (gap=+0.0179)
#   Time : 64.7s
#   ★ New best! Val Acc = 0.8206
#
# Epoch  15/60  🔥 P2  lr=4.92e-05
# --------------------------------------------------
#   Train: loss=0.7514  acc=0.8484
#   Val  : loss=0.8138  acc=0.8448  (gap=+0.0036)
#   Time : 65.4s
#   ★ New best! Val Acc = 0.8448
#
# Epoch  16/60  🔥 P2  lr=4.88e-05
# --------------------------------------------------
#   Train: loss=0.7114  acc=0.8731
#   Val  : loss=0.8134  acc=0.8383  (gap=+0.0347)
#   Time : 64.6s
#
# Epoch  17/60  🔥 P2  lr=4.82e-05
# --------------------------------------------------
#   Train: loss=0.6927  acc=0.8820
#   Val  : loss=0.7985  acc=0.8490  (gap=+0.0330)
#   Time : 66.4s
#   ★ New best! Val Acc = 0.8490
#
# Epoch  18/60  🔥 P2  lr=4.76e-05
# --------------------------------------------------
#   Train: loss=0.6577  acc=0.8989
#   Val  : loss=0.7827  acc=0.8569  (gap=+0.0420)
#   Time : 65.7s
#   ★ New best! Val Acc = 0.8569
#
# Epoch  19/60  🔥 P2  lr=4.69e-05
# --------------------------------------------------
#   Train: loss=0.6334  acc=0.9090
#   Val  : loss=0.7646  acc=0.8691  (gap=+0.0400)
#   Time : 65.5s
#   ★ New best! Val Acc = 0.8691
#
# Epoch  20/60  🔥 P2  lr=4.61e-05
# --------------------------------------------------
#   Train: loss=0.6247  acc=0.9144
#   Val  : loss=0.7693  acc=0.8709  (gap=+0.0435)
#   Time : 65.2s
#   ★ New best! Val Acc = 0.8709
#   ⏳ Early stop counter: 1/12
#
# Epoch  21/60  🔥 P2  lr=4.52e-05
# --------------------------------------------------
#   Train: loss=0.6148  acc=0.9179
#   Val  : loss=0.7586  acc=0.8714  (gap=+0.0465)
#   Time : 65.2s
#   ★ New best! Val Acc = 0.8714
#
# Epoch  22/60  🔥 P2  lr=4.43e-05
# --------------------------------------------------
#   Train: loss=0.6027  acc=0.9251
#   Val  : loss=0.7582  acc=0.8709  (gap=+0.0542)
#   Time : 65.3s
#
# Epoch  23/60  🔥 P2  lr=4.32e-05
# --------------------------------------------------
#   Train: loss=0.5790  acc=0.9320
#   Val  : loss=0.7616  acc=0.8672  (gap=+0.0648)
#   Time : 65.1s
#   ⏳ Early stop counter: 1/12
#
# Epoch  24/60  🔥 P2  lr=4.21e-05
# --------------------------------------------------
#   Train: loss=0.5700  acc=0.9390
#   Val  : loss=0.7520  acc=0.8756  (gap=+0.0634)
#   Time : 65.8s
#   ★ New best! Val Acc = 0.8756
#
# Epoch  25/60  🔥 P2  lr=4.09e-05
# --------------------------------------------------
#   Train: loss=0.5665  acc=0.9425
#   Val  : loss=0.7452  acc=0.8756  (gap=+0.0669)
#   Time : 65.7s
#
# Epoch  26/60  🔥 P2  lr=3.97e-05
# --------------------------------------------------
#   Train: loss=0.5506  acc=0.9478
#   Val  : loss=0.7413  acc=0.8770  (gap=+0.0708)
#   Time : 65.4s
#   ★ New best! Val Acc = 0.8770
#
# Epoch  27/60  🔥 P2  lr=3.84e-05
# --------------------------------------------------
#   Train: loss=0.5478  acc=0.9529
#   Val  : loss=0.7531  acc=0.8686  (gap=+0.0843)
#   Time : 66.4s
#   ⏳ Early stop counter: 1/12
#
# Epoch  28/60  🔥 P2  lr=3.70e-05
# --------------------------------------------------
#   Train: loss=0.5400  acc=0.9531
#   Val  : loss=0.7444  acc=0.8733  (gap=+0.0798)
#   Time : 66.7s
#   ⏳ Early stop counter: 2/12
#
# Epoch  29/60  🔥 P2  lr=3.56e-05
# --------------------------------------------------
#   Train: loss=0.5321  acc=0.9575
#   Val  : loss=0.7560  acc=0.8728  (gap=+0.0847)
#   Time : 66.3s
#   ⏳ Early stop counter: 3/12
#
# Epoch  30/60  🔥 P2  lr=3.42e-05
# --------------------------------------------------
#   Train: loss=0.5273  acc=0.9585
#   Val  : loss=0.7491  acc=0.8774  (gap=+0.0811)
#   Time : 65.9s
#   ★ New best! Val Acc = 0.8774
#   ⏳ Early stop counter: 4/12
#
# Epoch  31/60  🔥 P2  lr=3.27e-05
# --------------------------------------------------
#   Train: loss=0.5249  acc=0.9612
#   Val  : loss=0.7507  acc=0.8793  (gap=+0.0819)
#   Time : 66.2s
#   ★ New best! Val Acc = 0.8793
#   ⏳ Early stop counter: 5/12
#
# Epoch  32/60  🔥 P2  lr=3.12e-05
# --------------------------------------------------
#   Train: loss=0.5169  acc=0.9654
#   Val  : loss=0.7589  acc=0.8695  (gap=+0.0959)
#   Time : 65.5s
#   ⏳ Early stop counter: 6/12
#
# Epoch  33/60  🔥 P2  lr=2.97e-05
# --------------------------------------------------
#   Train: loss=0.5146  acc=0.9664
#   Val  : loss=0.7489  acc=0.8751  (gap=+0.0913)
#   Time : 66.1s
#   ⏳ Early stop counter: 7/12
#
# Epoch  34/60  🔥 P2  lr=2.81e-05
# --------------------------------------------------
#   Train: loss=0.5176  acc=0.9646
#   Val  : loss=0.7519  acc=0.8714  (gap=+0.0932)
#   Time : 65.2s
#   ⏳ Early stop counter: 8/12
#
# Epoch  35/60  🔥 P2  lr=2.66e-05
# --------------------------------------------------
#   Train: loss=0.5081  acc=0.9690
#   Val  : loss=0.7479  acc=0.8751  (gap=+0.0939)
#   Time : 65.1s
#   ⏳ Early stop counter: 9/12
#
# Epoch  36/60  🔥 P2  lr=2.50e-05
# --------------------------------------------------
#   Train: loss=0.5035  acc=0.9724
#   Val  : loss=0.7482  acc=0.8737  (gap=+0.0986)
#   Time : 65.6s
#   ⏳ Early stop counter: 10/12
#
# Epoch  37/60  🔥 P2  lr=2.34e-05
# --------------------------------------------------
#   Train: loss=0.4999  acc=0.9737
#   Val  : loss=0.7450  acc=0.8812  (gap=+0.0925)
#   Time : 65.9s
#   ★ New best! Val Acc = 0.8812
#   ⏳ Early stop counter: 11/12
#
# Epoch  38/60  🔥 P2  lr=2.19e-05
# --------------------------------------------------
#   Train: loss=0.4935  acc=0.9753
#   Val  : loss=0.7509  acc=0.8756  (gap=+0.0998)
#   Time : 65.4s
#   ⏳ Early stop counter: 12/12
#
#   🛑 Early Stopping! Val loss không cải thiện sau 12 epoch.
#      Dừng tại epoch 38, best model tại epoch 37.
#
# ======================================================================
#   HOÀN TẤT HUẤN LUYỆN
#   Tổng thời gian  : 40.7 phút
#   Best epoch      : 37
#   Best val acc    : 0.8812
#   Kết thúc epoch  : 38
# ======================================================================
# [INFO] Đã lưu biểu đồ: /kaggle/working/waste-detection2-Stage/results/classifier_runs/training_curves.png
# Figure(1800x500)
#
# ======================================================================
#   KẾT QUẢ TRÊN TẬP TEST
# ======================================================================
#   Test Loss     : 0.7329
#   Test Accuracy : 0.8855
# ======================================================================
#
#   CHI TIẾT TỪNG LỚP:
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#   Background     0.9657    0.9850    0.9752       400
#        Glass     0.8902    0.8639    0.8769       169
#        Metal     0.8283    0.8913    0.8586       276
#        Other     0.8839    0.8420    0.8624       443
#        Paper     0.9167    0.9041    0.9103       365
#      Plastic     0.8220    0.8259    0.8239       425
#
#     accuracy                         0.8855      2078
#    macro avg     0.8845    0.8854    0.8846      2078
# weighted avg     0.8859    0.8855    0.8854      2078
#
# [INFO] Đã lưu confusion matrix: /kaggle/working/waste-detection2-Stage/results/classifier_runs/confusion_matrix.png
# Figure(800x700)
# [INFO] Đã lưu checkpoint: /kaggle/working/waste-detection2-Stage/results/classifier_runs/stage2_efficientnet_b2_best.pth
# [INFO] Đã copy weights → /kaggle/working/waste-detection2-Stage/models/stage2_best.pth
# [INFO] Đã lưu history: /kaggle/working/waste-detection2-Stage/results/classifier_runs/training_history.json
#
# ======================================================================
#   HOÀN TẤT HUẤN LUYỆN STAGE 2 – CLASSIFIER (Cải tiến)
# ======================================================================
#   Model            : EfficientNet-B2 (6 lớp)
#   Lớp              : Background, Glass, Metal, Other, Paper, Plastic
#   Kỹ thuật mới     : Freeze→Unfreeze, Dropout(0.4), RandAugment,
#                      LabelSmoothing(0.1), EarlyStopping
#   Best epoch       : 37 (/38 epoch thực tế)
#   Best val acc     : 0.8812
#   Test accuracy    : 0.8855
#   Overfitting gap  : +0.0925 (tại best epoch)
#   Weights          : /kaggle/working/waste-detection2-Stage/models/stage2_best.pth
#   Training curves  : /kaggle/working/waste-detection2-Stage/results/classifier_runs/training_curves.png
#   Confusion matrix : /kaggle/working/waste-detection2-Stage/results/classifier_runs/confusion_matrix.png
# ======================================================================
#
#   So sánh với phiên bản gốc (nếu có cải thiện):
#   Gốc  → Best val acc = 70.1% (epoch 6/50, gap ≈ 30%)
#   Mới  → Best val acc = 88.1% (epoch 37, gap ≈ 9.2%)
# [DONE] Pipeline 2 giai đoạn hoàn tất!
#   Stage 1: YOLO binary detector  → phát hiện vùng chứa rác
#   Stage 2: EfficientNet-B2       → phân loại 6 lớp: Background, Glass, Metal, Other, Paper, Plastic
#   → Sẵn sàng ghép vào pipeline inference.

# %%
# ============================================================
# 6. Đánh giá Toàn Trình (End-to-End 2-Stage Pipeline)
# ============================================================
# Bước này mô phỏng luồng chạy thực tế: Đưa ảnh vào YOLO -> Cắt rác -> Phân loại

# !python src/evaluate_2stage.py \
  --detector stage1_best.pt \
  --classifier models/stage2_best.pth \
  --data-dir data/processed_binary/images/test \
  --label-dir data/processed/labels/test \
  --conf 0.15 \
  --output results/2stage_eval

print("\n✅ ĐÁNH GIÁ HOÀN TẤT! Kết quả được lưu tại results/2stage_eval")
# Out:
# [INFO] Đang sử dụng thiết bị: cuda
# Traceback (most recent call last):
#   File "/kaggle/working/waste-detection2-Stage/src/evaluate_2stage.py", line 238, in <module>
#     main()
#   File "/kaggle/working/waste-detection2-Stage/src/evaluate_2stage.py", line 185, in main
#     detector = TwoStageDetector(args.detector, args.classifier, args.conf)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/waste-detection2-Stage/src/inference_2stage.py", line 119, in __init__
#     self.classifier = load_classifier(Path(classifier_path), self.device)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/waste-detection2-Stage/src/inference_2stage.py", line 48, in load_classifier
#     model.load_state_dict(checkpoint['model_state_dict'])
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 2635, in load_state_dict
#     raise RuntimeError(
# RuntimeError: Error(s) in loading state_dict for EfficientNet:
# 	Missing key(s) in state_dict: "classifier.weight", "classifier.bias".
# 	Unexpected key(s) in state_dict: "classifier.1.weight", "classifier.1.bias".
#
# ✅ ĐÁNH GIÁ HOÀN TẤT! Kết quả được lưu tại results/2stage_eval

# %%
# ============================================================
# 7. Zip tất cả kết quả để tải về
# ============================================================
import shutil

# Nén thư mục kết quả
shutil.make_archive("/kaggle/working/final_results", "zip", "/kaggle/working/waste-detection2-Stage/results")
print("\n📦 Đã nén toàn bộ logs, biểu đồ và kết quả: /kaggle/working/final_results.zip")

# Nén weights của model
if os.path.exists("/kaggle/working/waste-detection2-Stage/models"):
    shutil.make_archive("/kaggle/working/final_models", "zip", "/kaggle/working/waste-detection2-Stage/models")
    print("📦 Đã nén trọng số mô hình: /kaggle/working/final_models.zip")
# Out:
# 📦 Đã nén toàn bộ logs, biểu đồ và kết quả: /kaggle/working/final_results.zip
# 📦 Đã nén trọng số mô hình: /kaggle/working/final_models.zip
