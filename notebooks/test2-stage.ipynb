# %%
# !git clone https://github.com/Shiba-dotcom/waste-detection2-Stage.git
# Out:
# Cloning into 'waste-detection2-Stage'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 62 (delta 21), reused 57 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (62/62), 8.61 MiB | 34.73 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# !mkdir -p /kaggle/working/waste-detection2-Stage/data/external/TrashNet
# !mkdir -p /kaggle/working/waste-detection2-Stage/data/external/RealWaste
# !mkdir -p /kaggle/working/waste-detection2-Stage/data/raw

# %%
import os
import shutil
# Cấu hình danh sách các cặp đường dẫn (Nguồn -> Đích)
datasets_to_copy = [
    {
        "src": "/kaggle/input/datasets/feyzazkefe/trashnet/dataset-resized",
        "dst": "/kaggle/working/waste-detection2-Stage/data/external/TrashNet"
    },
    {
        # THÊM /data VÀO CUỐI ĐƯỜNG DẪN NÀY:
        "src": "/kaggle/input/datasets/sohamchaudhari2004/taco-trash-detection-dataset/data", 
        "dst": "/kaggle/working/waste-detection2-Stage/data/raw"
    },
    {
        "src": "/kaggle/input/datasets/joebeachcapital/realwaste/realwaste-main/RealWaste",
        "dst": "/kaggle/working/waste-detection2-Stage/data/external/RealWaste"
    }
]
print("Bắt đầu sao chép dữ liệu...\n")
for task in datasets_to_copy:
    src = task["src"]
    dst = task["dst"]
    if os.path.exists(src):
        # Tạo thư mục đích và các thư mục cha nếu chưa có
        os.makedirs(dst, exist_ok=True)
        # Sao chép toàn bộ nội dung bên trong src vào dst
        shutil.copytree(src, dst, dirs_exist_ok=True)
        print(f"Thành công: Nội dung inside '{os.path.basename(src)}' -> '{dst}'")
    else:
        print(f"Thất bại: Không tìm thấy thư mục nguồn: {src}")
print("\nHoàn thành tất cả các tác vụ!")
# Out:
# Bắt đầu sao chép dữ liệu...
#
# Thành công: Nội dung inside 'dataset-resized' -> '/kaggle/working/waste-detection2-Stage/data/external/TrashNet'
# Thành công: Nội dung inside 'data' -> '/kaggle/working/waste-detection2-Stage/data/raw'
# Thành công: Nội dung inside 'RealWaste' -> '/kaggle/working/waste-detection2-Stage/data/external/RealWaste'
#
# Hoàn thành tất cả các tác vụ!

# %%
# !pip install -q ultralytics timm 
# %cd /kaggle/working/waste-detection2-Stage
# !python src/data_prep/data_cleaning.py
# !python src/Training_dataYolo.py
# !python src/data_prep/split_dataset.py
# !python src/data_prep/crop_for_classification.py
# !python src/data_prep/merge_external_datasets.py

print("Xong tiền xử lý! Dữ liệu đã sẵn sàng.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.9 MB/s eta 0:00:0000:01
# /kaggle/working/waste-detection2-Stage
# [WARN] Khong tim thay annotations_cleaned.json, dung file goc
#        Hay chay 'python src/data_cleaning.py' truoc!
#
# [INFO] Đang xử lý chế độ: MULTI-CLASS (5 classes)...
#        Đang copy hình ảnh...
#        Đang tạo file nhãn YOLO...
#        => Đã xử lý xong (MULTI-CLASS (5 classes)).
#
# [INFO] Đang xử lý chế độ: BINARY (1 class: Waste)...
#        Đang copy hình ảnh...
#        Đang tạo file nhãn YOLO...
#        => Đã xử lý xong (BINARY (1 class: Waste)).
#
# [HOÀN TẤT] Cả 2 bộ dữ liệu đã được tạo thành công!
# Found 0 images
# Traceback (most recent call last):
#   File "/kaggle/working/waste-detection2-Stage/src/data_prep/split_dataset.py", line 120, in <module>
#     raise ValueError("No images found")
# ValueError: No images found
# ============================================================
#   CROP FOR CLASSIFICATION - Stage 2 Dataset
# ============================================================
#   Input  : /kaggle/working/waste-detection2-Stage/data/processed
#   Output : /kaggle/working/waste-detection2-Stage/data/classification
#   Crop size : 224x224
#   Padding   : 10%
#   Oversample (train only): {'Glass': 2, 'Metal': 1, 'Other': 0, 'Paper': 1, 'Plastic': 0}
# ============================================================
# [WARN] Khong tim thay: /kaggle/working/waste-detection2-Stage/data/processed/images/train
#
#   [TRAIN] Tong: 0 crops
#     Glass     :     0
#     Metal     :     0
#     Other     :     0
#     Paper     :     0
#     Plastic   :     0
# [WARN] Khong tim thay: /kaggle/working/waste-detection2-Stage/data/processed/images/val
#
#   [VAL] Tong: 0 crops
#     Glass     :     0
#     Metal     :     0
#     Other     :     0
#     Paper     :     0
#     Plastic   :     0
# [WARN] Khong tim thay: /kaggle/working/waste-detection2-Stage/data/processed/images/test
#
#   [TEST] Tong: 0 crops
#     Glass     :     0
#     Metal     :     0
#     Other     :     0
#     Paper     :     0
#     Plastic   :     0
#
# ============================================================
#   TONG CONG: 0 crops
#   Luu tai: /kaggle/working/waste-detection2-Stage/data/classification
# ============================================================
#
# [HOAN TAT] Crop xong! Dataset san sang cho Stage 2.
# =================================================================
#   MERGE EXTERNAL DATASETS - Classification Stage 2
# =================================================================
#   Moi truong  : Local
#   TACO crops  : /kaggle/working/waste-detection2-Stage/data/classification
#   TrashNet    : /kaggle/working/waste-detection2-Stage/data/external/TrashNet
#   RealWaste   : /kaggle/working/waste-detection2-Stage/data/external/RealWaste
#   Output      : /kaggle/working/waste-detection2-Stage/data/classification_merged
#   Max/class   : 2500
# =================================================================
#
# [Buoc 1] Thu thap TACO crops...
#   [WARN] Khong tim thay: /kaggle/working/waste-detection2-Stage/data/classification/train
#   [WARN] Khong tim thay: /kaggle/working/waste-detection2-Stage/data/classification/val
#   [WARN] Khong tim thay: /kaggle/working/waste-detection2-Stage/data/classification/test
#
# [Buoc 2] Thu thap TrashNet...
#   Glass     :   501
#   Metal     :   410
#   Other     :   137
#   Paper     :   997
#   Plastic   :   482
#
# [Buoc 3] Thu thap RealWaste...
#   Glass     :   420
#   Metal     :   790
#   Other     :  1660
#   Paper     :   961
#   Plastic   :   921
#
# [Buoc 4] Chia dataset ngoai thanh train/val/test...
#   Glass     : train= 645 val= 138 test= 138
#   Metal     : train= 840 val= 180 test= 180
#   Other     : train=1259 val= 269 test= 269
#   Paper     : train=1372 val= 293 test= 293
#   Plastic   : train= 983 val= 210 test= 210
#
# [Buoc 5] Gop va copy anh...
#
#   --- TRAIN ---
#     Glass     : 0 (TACO) + 645 (ext) = 645
#     Metal     : 0 (TACO) + 840 (ext) = 840
#     Other     : 0 (TACO) + 1259 (ext) = 1259
#     Paper     : 0 (TACO) + 1372 (ext) = 1372
#     Plastic   : 0 (TACO) + 983 (ext) = 983
#
#   --- VAL ---
#     Glass     : 0 (TACO) + 138 (ext) = 138
#     Metal     : 0 (TACO) + 180 (ext) = 180
#     Other     : 0 (TACO) + 269 (ext) = 269
#     Paper     : 0 (TACO) + 293 (ext) = 293
#     Plastic   : 0 (TACO) + 210 (ext) = 210
#
#   --- TEST ---
#     Glass     : 0 (TACO) + 138 (ext) = 138
#     Metal     : 0 (TACO) + 180 (ext) = 180
#     Other     : 0 (TACO) + 269 (ext) = 269
#     Paper     : 0 (TACO) + 293 (ext) = 293
#     Plastic   : 0 (TACO) + 210 (ext) = 210
#
# =================================================================
#   THONG KE CUOI CUNG
# =================================================================
#
#   [TRAIN] Tong: 5099
#     Glass     :   645  █████████████████████
#     Metal     :   840  ████████████████████████████
#     Other     :  1259  █████████████████████████████████████████
#     Paper     :  1372  █████████████████████████████████████████████
#     Plastic   :   983  ████████████████████████████████
#
#   [VAL] Tong: 1090
#     Glass     :   138  ████
#     Metal     :   180  ██████
#     Other     :   269  ████████
#     Paper     :   293  █████████
#     Plastic   :   210  ███████
#
#   [TEST] Tong: 1090
#     Glass     :   138  ████
#     Metal     :   180  ██████
#     Other     :   269  ████████
#     Paper     :   293  █████████
#     Plastic   :   210  ███████
#
#   Ty le max/min (train): 2.1:1
#   [OK] Can bang tot!
#
#   Dataset merged luu tai: /kaggle/working/waste-detection2-Stage/data/classification_merged
# =================================================================
# [HOAN TAT] Merge xong!
# Xong tiền xử lý! Dữ liệu đã sẵn sàng.

# %%
# !python src/train_stage1_detector.py
# !python src/train_stage2_classifier.py
